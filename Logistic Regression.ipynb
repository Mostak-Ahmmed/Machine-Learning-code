# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('/diabetes.csv')
dataset.head(10)

# %%
data = {
    'Pregnancies': [0, 1, 2],
    'Glucose': [85, 90, 95],
    'BloodPressure': [70, 80, 75],
    'SkinThickness': [20, 25, 30],
    'Insulin': [0, 100, 150],
    'BMI': [25.0, 30.0, 28.0],
    'DiabetesPedigreeFunction': [0.5, 0.6, 0.4],
    'Age': [21, 22, 23],
    'Outcome': [0, 1, 1]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Check the DataFrame columns
print(df.columns)

# Assuming you want to plot 'Pregnancies' vs 'Glucose'
df.plot(x='Pregnancies', y='Glucose', style='o')
plt.title('Pregnancies vs Glucose')
plt.xlabel('Number of Pregnancies')
plt.ylabel('Glucose Level')
plt.show()
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X, y, test_size =0.2, random_state =0)


print(X_test)
print(y_test)
# Out:
# [[1.000e+00 1.990e+02 7.600e+01 ... 4.290e+01 1.394e+00 2.200e+01]
#  [2.000e+00 1.070e+02 7.400e+01 ... 3.360e+01 4.040e-01 2.300e+01]
#  [4.000e+00 7.600e+01 6.200e+01 ... 3.400e+01 3.910e-01 2.500e+01]
#  ...
#  [4.000e+00 1.420e+02 8.600e+01 ... 4.400e+01 6.450e-01 2.200e+01]
#  [3.000e+00 1.160e+02 7.400e+01 ... 2.630e+01 1.070e-01 2.400e+01]
#  [1.000e+00 1.070e+02 7.200e+01 ... 3.080e+01 8.210e-01 2.400e+01]]
# [199 107  76 166 111  81 152 176 127 103 158 187 114  82  65 108 179  73
#  132  99 144 118  87  61  97 124 104 153 112 110 136 102 102 122 119 168
#  136 117 119 180 119  90  99 193 197 102 108 129 109 125 133 108 151 137
#   91   0  85 115 134 115 167 147 125 138 182 197 165 122 106  72 108 119
#   86 183 171 137  68 154  83  97 100 136 110  97  95  92 139 103 181  94
#  124 129 113 103 164 111  97 152 111 115 114  99 110  95 128 108 126 137
#   99 183  88 112 143 128 173 161 108 193 111 120 112 103 115 121 143  90
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression ()
regressor.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 2.842170943040401e-14
# [-4.69763808e-16  1.00000000e+00  1.38777878e-16  2.08166817e-16
#   6.66133815e-16 -1.03649728e-16 -7.59592042e-16 -1.11022302e-16]

# %%
import pandas as pd

# Example data (ensure y_test and y_pred are defined correctly in your context)
# y_test and y_pred should be numpy arrays or pandas Series
y_test = [1, 0, 1, 1, 0]  # Replace with your actual test labels
y_pred = [1, 0, 0, 1, 1]  # Replace with your predicted values from the model

# Create a DataFrame to compare actual vs predicted values
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    Actual  Predicted
# 0       1          1
# 1       0          0
# 2       1          0
# 3       1          1
# 4       0          1

# %%
from sklearn import metrics
print('Mean Squared Error:', metrics.mean_squared_error(y_test , y_pred))
# Out:
# Mean Squared Error: 0.4
